# %%
import pandas as pd #import pandas

# %%
data = pd.read_csv('titanic/train.csv') #comma separed values, valores separados por vírgula

# %%
data.columns = ['PassageiroID', 'Sobreviventes', 'Classe', 'Nome', 'Sexo', 'Idade', 'IrmaosParesAmorosos',
       'PaisFilhos', 'Bilhete', 'Tarifa', 'Cabine', 'Embarque']

# %%
data.head()
# Out:
#    PassageiroID  Sobreviventes  Classe  \
# 0             1              0       3
# 1             2              1       1
# 2             3              1       3
# 3             4              1       1
# 4             5              0       3
#
#                                                 Nome    Sexo  Idade  \
# 0                            Braund, Mr. Owen Harris    male   22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                             Heikkinen, Miss. Laina  female   26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                           Allen, Mr. William Henry    male   35.0
#
#    IrmaosParesAmorosos  PaisFilhos           Bilhete   Tarifa Cabine Embarque
# 0                    1           0         A/5 21171   7.2500    NaN        S
# 1                    1           0          PC 17599  71.2833    C85        C
# 2                    0           0  STON/O2. 3101282   7.9250    NaN        S
# ...

# %%
data['Idade'].mean() #média
# Out:
# 29.69911764705882

# %%
data['Idade'].sum() #somatório
# Out:
# 21205.17

# %%
data['Idade'].count() #quantidade de idades
# Out:
# 714

# %%
data['Idade'].median() #mediana
# Out:
# 28.0

# %%
data['Idade'].mode() #moda
# Out:
# 0    24.0
# dtype: float64

# %%
data['Idade'].max() #valor máximo
# Out:
# 80.0

# %%
data['Idade'].min() #valor mínimo
# Out:
# 0.42

# %%
data['Idade'].idxmin() #index do valor minimo
# Out:
# 803

# %%
data['Idade'].idxmax() #index do valor maximo
# Out:
# 630

# %%
data.mean()
# Out:
# PassageiroID           446.000000
# Sobreviventes            0.383838
# Classe                   2.308642
# Idade                   29.699118
# IrmaosParesAmorosos      0.523008
# PaisFilhos               0.381594
# Tarifa                  32.204208
# dtype: float64

# %%
data.sum()
# Out:
# PassageiroID                                                      397386
# Sobreviventes                                                        342
# Classe                                                              2057
# Nome                   Braund, Mr. Owen HarrisCumings, Mrs. John Brad...
# Sexo                   malefemalefemalefemalemalemalemalemalefemalefe...
# Idade                                                            21205.2
# IrmaosParesAmorosos                                                  466
# PaisFilhos                                                           340
# Bilhete                A/5 21171PC 17599STON/O2. 31012821138033734503...
# Tarifa                                                           28693.9
# dtype: object

# %%
data.min()
# Out:
# PassageiroID                             1
# Sobreviventes                            0
# Classe                                   1
# Nome                   Abbing, Mr. Anthony
# Sexo                                female
# Idade                                 0.42
# IrmaosParesAmorosos                      0
# PaisFilhos                               0
# Bilhete                             110152
# Tarifa                                   0
# dtype: object

# %%
data
# Out:
#      PassageiroID  Sobreviventes  Classe  \
# 0               1              0       3
# 1               2              1       1
# 2               3              1       3
# 3               4              1       1
# 4               5              0       3
# ..            ...            ...     ...
# 886           887              0       2
# 887           888              1       1
# 888           889              0       3
# 889           890              1       1
# 890           891              0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ...

# %%
data.iloc[630] #ver o que está em uma posição (index)
# Out:
# PassageiroID                                            631
# Sobreviventes                                             1
# Classe                                                    1
# Nome                   Barkworth, Mr. Algernon Henry Wilson
# Sexo                                                   male
# Idade                                                    80
# IrmaosParesAmorosos                                       0
# PaisFilhos                                                0
# Bilhete                                               27042
# Tarifa                                                   30
# Cabine                                                  A23
# Embarque                                                  S
# Name: 630, dtype: object

# %%
data.iloc[803] #ver o que está em uma posição (index) - data series
# Out:
# PassageiroID                                       804
# Sobreviventes                                        1
# Classe                                               3
# Nome                   Thomas, Master. Assad Alexander
# Sexo                                              male
# Idade                                             0.42
# IrmaosParesAmorosos                                  0
# PaisFilhos                                           1
# Bilhete                                           2625
# Tarifa                                          8.5167
# Cabine                                             NaN
# Embarque                                             C
# Name: 803, dtype: object

# %%
data.iloc[[630]] #ver o que está em uma posição (index)
# Out:
#      PassageiroID  Sobreviventes  Classe  \
# 630           631              1       1
#
#                                      Nome  Sexo  Idade  IrmaosParesAmorosos  \
# 630  Barkworth, Mr. Algernon Henry Wilson  male   80.0                    0
#
#      PaisFilhos Bilhete  Tarifa Cabine Embarque
# 630           0   27042    30.0    A23        S

# %%
data.iloc[[330,220,110]]
# Out:
#      PassageiroID  Sobreviventes  Classe                            Nome  \
# 330           331              1       3              McCoy, Miss. Agnes
# 220           221              1       3  Sunderland, Mr. Victor Francis
# 110           111              0       1  Porter, Mr. Walter Chamberlain
#
#        Sexo  Idade  IrmaosParesAmorosos  PaisFilhos          Bilhete  Tarifa  \
# 330  female    NaN                    2           0           367226   23.25
# 220    male   16.0                    0           0  SOTON/OQ 392089    8.05
# 110    male   47.0                    0           0           110465   52.00
#
#     Cabine Embarque
# 330    NaN        Q
# 220    NaN        S
# 110   C110        S

# %%
data.iloc[880:]
# Out:
#      PassageiroID  Sobreviventes  Classe  \
# 880           881              1       2
# 881           882              0       3
# 882           883              0       3
# 883           884              0       2
# 884           885              0       3
# 885           886              0       3
# 886           887              0       2
# 887           888              1       1
# 888           889              0       3
# 889           890              1       1
# 890           891              0       3
#
#                                              Nome    Sexo  Idade  \
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female   25.0
# 881                            Markun, Mr. Johann    male   33.0
# 882                  Dahlberg, Miss. Gerda Ulrika  female   22.0
# 883                 Banfield, Mr. Frederick James    male   28.0
# 884                        Sutehall, Mr. Henry Jr    male   25.0
# 885          Rice, Mrs. William (Margaret Norton)  female   39.0
# ...

# %%
data['Classe'].iloc[2] #classe do passageiro de index 2
# Out:
# 3

# %%
data['Nome'].iloc[2] #nome do passageiro index 2
# Out:
# 'Heikkinen, Miss. Laina'

# %%
data[['Nome', 'Sexo', 'Idade', 'Tarifa', 'Classe', 'Sobreviventes']].loc[data['Sexo']=='male'] #Pesquisar Nome, Sexo, Idade, Tarifa, Classe e Sobreviventes somente de homens
# Out:
#                                Nome  Sexo  Idade   Tarifa  Classe  \
# 0           Braund, Mr. Owen Harris  male   22.0   7.2500       3
# 4          Allen, Mr. William Henry  male   35.0   8.0500       3
# 5                  Moran, Mr. James  male    NaN   8.4583       3
# 6           McCarthy, Mr. Timothy J  male   54.0  51.8625       1
# 7    Palsson, Master. Gosta Leonard  male    2.0  21.0750       3
# ..                              ...   ...    ...      ...     ...
# 883   Banfield, Mr. Frederick James  male   28.0  10.5000       2
# 884          Sutehall, Mr. Henry Jr  male   25.0   7.0500       3
# 886           Montvila, Rev. Juozas  male   27.0  13.0000       2
# 889           Behr, Mr. Karl Howell  male   26.0  30.0000       1
# 890             Dooley, Mr. Patrick  male   32.0   7.7500       3
#
#      Sobreviventes
# 0                0
# 4                0
# 5                0
# 6                0
# 7                0
# ..             ...
# 883              0
# ...

# %%
data[['Nome', 'Sexo', 'Idade','Tarifa', 'Classe', 'Sobreviventes']].loc[data['Idade']==1] #Pesquisar Nome, Sexo, Tarifa, Classe e Sobreviventes somente de bebes
# Out:
#                                 Nome    Sexo  Idade   Tarifa  Classe  \
# 164     Panula, Master. Eino Viljami    male    1.0  39.6875       3
# 172     Johnson, Miss. Eleanor Ileen  female    1.0  11.1333       3
# 183        Becker, Master. Richard F    male    1.0  39.0000       2
# 381      Nakid, Miss. Maria ("Mary")  female    1.0  15.7417       3
# 386  Goodwin, Master. Sidney Leonard    male    1.0  46.9000       3
# 788       Dean, Master. Bertram Vere    male    1.0  20.5750       3
# 827            Mallet, Master. Andre    male    1.0  37.0042       2
#
#      Sobreviventes
# 164              0
# 172              1
# 183              1
# 381              1
# 386              0
# 788              1
# 827              1

# %%
data[['Nome', 'Sexo', 'Idade', 'Tarifa', 'Classe', 'Sobreviventes']].loc[data['Idade']>64] #Pesquisar Nome, Sexo, Idade, Tarifa, Classe e Sobreviventes somente de idosos (65 anos ++)
# Out:
#                                      Nome  Sexo  Idade   Tarifa  Classe  \
# 33                  Wheadon, Mr. Edward H  male   66.0  10.5000       2
# 54         Ostby, Mr. Engelhart Cornelius  male   65.0  61.9792       1
# 96              Goldschmidt, Mr. George B  male   71.0  34.6542       1
# 116                  Connors, Mr. Patrick  male   70.5   7.7500       3
# 280                      Duane, Mr. Frank  male   65.0   7.7500       3
# 456             Millet, Mr. Francis Davis  male   65.0  26.5500       1
# 493               Artagaveytia, Mr. Ramon  male   71.0  49.5042       1
# 630  Barkworth, Mr. Algernon Henry Wilson  male   80.0  30.0000       1
# 672           Mitchell, Mr. Henry Michael  male   70.0  10.5000       2
# 745          Crosby, Capt. Edward Gifford  male   70.0  71.0000       1
# 851                   Svensson, Mr. Johan  male   74.0   7.7750       3
#
#      Sobreviventes
# 33               0
# 54               0
# 96               0
# 116              0
# ...

# %%
data[['Nome', 'Sexo', 'Idade', 'Tarifa', 'Classe', 'Sobreviventes']]\
.loc[(data['Idade']>2) & (data['Idade']< 17)] #Pesquisar Nome, Sexo, Idade, Tarifa, Classe e Sobreviventes somente crianças e adolescentes entre 3 até 16 anos
# Out:
#                                         Nome    Sexo  Idade   Tarifa  Classe  \
# 9        Nasser, Mrs. Nicholas (Adele Achem)  female   14.0  30.0708       2
# 10           Sandstrom, Miss. Marguerite Rut  female    4.0  16.7000       3
# 14      Vestrom, Miss. Hulda Amanda Adolfina  female   14.0   7.8542       3
# 22               McGowan, Miss. Anna "Annie"  female   15.0   8.0292       3
# 24             Palsson, Miss. Torborg Danira  female    8.0  21.0750       3
# ..                                       ...     ...    ...      ...     ...
# 850  Andersson, Master. Sigvard Harald Elias    male    4.0  31.2750       3
# 852                  Boulos, Miss. Nourelain  female    9.0  15.2458       3
# 853                Lines, Miss. Mary Conover  female   16.0  39.4000       1
# 869          Johnson, Master. Harold Theodor    male    4.0  11.1333       3
# 875         Najib, Miss. Adele Kiamie "Jane"  female   15.0   7.2250       3
#
#      Sobreviventes
# 9                1
# ...

# %%
data[['Nome', 'Sexo', 'Idade', 'Tarifa', 'Classe', 'Sobreviventes']]\
.loc[(data['Sexo']=='female') & (data['Sobreviventes']== 1)].mean() #Pesquisar Nome, Sexo, Idade, Tarifa, Classe e Sobreviventes somente crianças e adolescentes entre 3 até 16 anos e que sobreviveram
# Out:
# Idade            28.847716
# Tarifa           51.938573
# Classe            1.918455
# Sobreviventes     1.000000
# dtype: float64

# %%
data['Sexo'].map({'male': 'homem', 'female': 'mulher'}).head() #map para trocar nome de objetos utilizando dicionário
# Out:
# 0     homem
# 1    mulher
# 2    mulher
# 3    mulher
# 4     homem
# Name: Sexo, dtype: object

# %%
data['Sexo'].replace({'male': 'homem', 'female': 'mulher'}).head() #replace para trocar nome de objetos utilizando dicionário
# Out:
# 0     homem
# 1    mulher
# 2    mulher
# 3    mulher
# 4     homem
# Name: Sexo, dtype: object

# %%
data['Sexo'].replace(['male', 'female'], ['homem', 'mulher']).head() ##replace para trocar nome de objetos utilizando lista
# Out:
# 0     homem
# 1    mulher
# 2    mulher
# 3    mulher
# 4     homem
# Name: Sexo, dtype: object

# %%
data['Sexo'].replace(['male', 'female'], 'pessoa').head() ##replace para trocar nome de objetos utilizando lista
# Out:
# 0    pessoa
# 1    pessoa
# 2    pessoa
# 3    pessoa
# 4    pessoa
# Name: Sexo, dtype: object

# %%
data['Sexo'] = data['Sexo'].map({'male': 'homem', 'female': 'mulher'}) #map para trocar nome de objetos utilizando dicionário

# %%
data
# Out:
#      PassageiroID  Sobreviventes  Classe  \
# 0               1              0       3
# 1               2              1       1
# 2               3              1       3
# 3               4              1       1
# 4               5              0       3
# ..            ...            ...     ...
# 886           887              0       2
# 887           888              1       1
# 888           889              0       3
# 889           890              1       1
# 890           891              0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris   homem   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 2                               Heikkinen, Miss. Laina  mulher   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 4                             Allen, Mr. William Henry   homem   35.0
# ...

# %%
data.groupby('Sexo').sum() #Agrupar as colunas por sexo e mostrar a soma resultante em cada coluna
# Out:
#         PassageiroID  Sobreviventes  Classe     Idade  IrmaosParesAmorosos  \
# Sexo
# homem         262043            109    1379  13919.17                  248
# mulher        135343            233     678   7286.00                  218
#
#         PaisFilhos      Tarifa
# Sexo
# homem          136  14727.2865
# mulher         204  13966.6628

# %%
data.groupby('Classe').mean() #Agrupar as colunas por classe e mostrar a média de cada uma coluna
# Out:
#         PassageiroID  Sobreviventes      Idade  IrmaosParesAmorosos  \
# Classe
# 1         461.597222       0.629630  38.233441             0.416667
# 2         445.956522       0.472826  29.877630             0.402174
# 3         439.154786       0.242363  25.140620             0.615071
#
#         PaisFilhos     Tarifa
# Classe
# 1         0.356481  84.154687
# 2         0.380435  20.662183
# 3         0.393075  13.675550

# %%
data.groupby('Sobreviventes').mean() #Agrupar as colunas por sobreviventes e mostrar a média de cada uma coluna
# Out:
#                PassageiroID    Classe      Idade  IrmaosParesAmorosos  \
# Sobreviventes
# 0                447.016393  2.531876  30.626179             0.553734
# 1                444.368421  1.950292  28.343690             0.473684
#
#                PaisFilhos     Tarifa
# Sobreviventes
# 0                0.329690  22.117887
# 1                0.464912  48.395408

# %%
data.groupby(['Sexo','Classe']).mean() #Agrupar as colunas por sexo e classe e mostrar a média relacionando ambas colunas
# Out:
#                PassageiroID  Sobreviventes      Idade  IrmaosParesAmorosos  \
# Sexo   Classe
# homem  1         455.729508       0.368852  41.281386             0.311475
#        2         447.962963       0.157407  30.740707             0.342593
#        3         455.515850       0.135447  26.507589             0.498559
# mulher 1         469.212766       0.968085  34.611765             0.553191
#        2         443.105263       0.921053  28.722973             0.486842
#        3         399.729167       0.500000  21.750000             0.895833
#
#                PaisFilhos      Tarifa
# Sexo   Classe
# homem  1         0.278689   67.226127
#        2         0.222222   19.741782
#        3         0.224784   12.661633
# mulher 1         0.457447  106.125798
#        2         0.605263   21.970121
#        3         0.798611   16.118810

# %%
pd.crosstab(data['Sobreviventes'], data['Classe'], margins='True') #Cruzar as colunas Sobreviventes e Classe, magins = somatório total
# Out:
# Classe           1    2    3  All
# Sobreviventes
# 0               80   97  372  549
# 1              136   87  119  342
# All            216  184  491  891

# %%
pd.crosstab(data['Sobreviventes'], data['Sexo'], margins='True') #Cruzar as colunas Sobreviventes e Sexo, magins = somatório total
# Out:
# Sexo           homem  mulher  All
# Sobreviventes
# 0                468      81  549
# 1                109     233  342
# All              577     314  891

# %%
pd.crosstab(data['Sobreviventes'], data['Sexo'], margins='True').style.background_gradient(cmap='Blues') 
#Cruzar as colunas Sobreviventes e Sexo, magins = somatório total. Em azul, os maiores valores
# Out:
# <style  type="text/css" >
#     #T_2cf5f3e6_d639_11ec_84ee_69938289243erow0_col0 {
#             background-color:  #1d6cb1;
#             color:  #f1f1f1;
#         }    #T_2cf5f3e6_d639_11ec_84ee_69938289243erow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2cf5f3e6_d639_11ec_84ee_69938289243erow0_col2 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_2cf5f3e6_d639_11ec_84ee_69938289243erow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2cf5f3e6_d639_11ec_84ee_69938289243erow1_col1 {
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }    #T_2cf5f3e6_d639_11ec_84ee_69938289243erow1_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_2cf5f3e6_d639_11ec_84ee_69938289243erow2_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
# ...

# %%
pd.crosstab(data['Sobreviventes'], data['Sexo'], margins='True').style.background_gradient(cmap='OrRd') 
#Cruzar as colunas Sobreviventes e Sexo, magins = somatório total. Em vermelho forte, os maiores valores
# Out:
# <style  type="text/css" >
#     #T_5b27f94e_d639_11ec_84ee_69938289243erow0_col0 {
#             background-color:  #d2291a;
#             color:  #f1f1f1;
#         }    #T_5b27f94e_d639_11ec_84ee_69938289243erow0_col1 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_5b27f94e_d639_11ec_84ee_69938289243erow0_col2 {
#             background-color:  #fdba83;
#             color:  #000000;
#         }    #T_5b27f94e_d639_11ec_84ee_69938289243erow1_col0 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_5b27f94e_d639_11ec_84ee_69938289243erow1_col1 {
#             background-color:  #e9583e;
#             color:  #000000;
#         }    #T_5b27f94e_d639_11ec_84ee_69938289243erow1_col2 {
#             background-color:  #fff7ec;
#             color:  #000000;
#         }    #T_5b27f94e_d639_11ec_84ee_69938289243erow2_col0 {
#             background-color:  #7f0000;
#             color:  #f1f1f1;
# ...
